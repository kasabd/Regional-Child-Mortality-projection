# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd

# %%
pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.11.1-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 6.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (4.4.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (5.9.0)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (2.2.2)
# Requirement already satisfied: nest-asyncio in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (1.5.6)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (2.2.2)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash) (2.28.1)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: Jinja2>=3.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask<2.3.0,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask<2.3.0,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Werkzeug<2.3.0->dash) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: six>=1.7.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, ansi2html, dash
# Successfully installed ansi2html-1.8.0 dash-2.11.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-tools
# Out:
# Collecting dash-tools
#   Downloading dash_tools-1.11.1-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 4.1 MB/s eta 0:00:0000:0100:010m
# Collecting yolk3k==0.9
#   Downloading yolk3k-0.9.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dash-mantine-components==0.10.2
#   Downloading dash_mantine_components-0.10.2-py3-none-any.whl (319 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Collecting packaging==21.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 943.2 kB/s eta 0:00:00
# Collecting dash-iconify==0.1.2
#   Downloading dash_iconify-0.1.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: pandas in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (1.5.3)
# Requirement already satisfied: Flask in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (2.2.2)
# Collecting pre-commit==2.16.0
#   Downloading pre_commit-2.16.0-py2.py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.6/191.6 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: dash>=2.5.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (2.11.1)
# Requirement already satisfied: setuptools>=65.5.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (65.6.3)
# Collecting gunicorn
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 2.6 MB/s eta 0:00:00
# Collecting visdcc==0.0.50
#   Downloading visdcc-0.0.50.tar.gz (518 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.8/518.8 kB 5.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ruamel.yaml==0.17.21 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (0.17.21)
# Collecting pipreqs==0.4.11
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: dash-bootstrap-components in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash-tools) (1.4.2)
# Collecting pytest==6.2.5
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 5.0 MB/s eta 0:00:0000:01
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from packaging==21.0->dash-tools) (3.0.9)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting identify>=1.0.0
#   Downloading identify-2.5.26-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: toml in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pre-commit==2.16.0->dash-tools) (0.10.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pre-commit==2.16.0->dash-tools) (6.0)
# Collecting virtualenv>=20.0.8
#   Downloading virtualenv-20.24.2-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.4 MB/s eta 0:00:0000:0100:01
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pytest==6.2.5->dash-tools) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pytest==6.2.5->dash-tools) (22.1.0)
# Requirement already satisfied: iniconfig in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pytest==6.2.5->dash-tools) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pytest==6.2.5->dash-tools) (1.11.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from ruamel.yaml==0.17.21->dash-tools) (0.2.6)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (5.9.0)
# Requirement already satisfied: retrying in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (1.3.4)
# Requirement already satisfied: dash-table==5.0.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (5.0.0)
# Requirement already satisfied: requests in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (2.28.1)
# Requirement already satisfied: ansi2html in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (1.8.0)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (2.2.2)
# Requirement already satisfied: nest-asyncio in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (1.5.6)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from dash>=2.5.1->dash-tools) (4.4.0)
# Requirement already satisfied: Jinja2>=3.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask->dash-tools) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask->dash-tools) (2.0.1)
# Requirement already satisfied: click>=8.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Flask->dash-tools) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pandas->dash-tools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pandas->dash-tools) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from pandas->dash-tools) (1.23.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from Jinja2>=3.0->Flask->dash-tools) (2.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.5.1->dash-tools) (8.0.1)
# Requirement already satisfied: six>=1.5 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->dash-tools) (1.16.0)
# Collecting filelock<4,>=3.12.2
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting distlib<1,>=0.3.7
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Collecting platformdirs<4,>=3.9.1
#   Downloading platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash>=2.5.1->dash-tools) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash>=2.5.1->dash-tools) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash>=2.5.1->dash-tools) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kasahunabdisa/anaconda3/lib/python3.10/site-packages (from requests->dash>=2.5.1->dash-tools) (1.26.14)
# Building wheels for collected packages: termcolor, visdcc, yolk3k, docopt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=09d51dc83a98759d474dd3b5f75973a4b4d786221df56b90da77c22174524e38
#   Stored in directory: /Users/kasahunabdisa/Library/Caches/pip/wheels/0c/e5/b9/02f085fda9a2abc47929943d09062e2c34bbc02a526f476a2e
#   Building wheel for visdcc (setup.py) ... done
#   Created wheel for visdcc: filename=visdcc-0.0.50-py3-none-any.whl size=518238 sha256=7992fed850f1c8a788a45ad78b93d94694af7ecdd1e6ad5fb7cbc0ee62ffcc1b
#   Stored in directory: /Users/kasahunabdisa/Library/Caches/pip/wheels/85/12/d7/4d76255781331fed1fe8283a87680b0305656d9aa1c6775983
#   Building wheel for yolk3k (setup.py) ... done
#   Created wheel for yolk3k: filename=yolk3k-0.9-py3-none-any.whl size=19857 sha256=8ed1c23aadf243bfbcfaf2fdcd41d3e69cc3f56fdd398a742dc821a700b4b1c4
#   Stored in directory: /Users/kasahunabdisa/Library/Caches/pip/wheels/35/ec/e6/b49390b45c43f26c538700b420bc33cc07f339493897370c11
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=305fc61937c62b66f4456d3f5fc4d6d759e91f476e984ded6b73fa9cc3a2b53d
#   Stored in directory: /Users/kasahunabdisa/Library/Caches/pip/wheels/7c/d7/8d/2156234738063e3d4a39ba77dc677046100e62766b53807189
# Successfully built termcolor visdcc yolk3k docopt
# Installing collected packages: yolk3k, visdcc, termcolor, docopt, distlib, dash-mantine-components, dash-iconify, platformdirs, packaging, nodeenv, identify, filelock, cfgv, yarg, virtualenv, pytest, gunicorn, pre-commit, pipreqs, dash-tools
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 2.5.2
#     Uninstalling platformdirs-2.5.2:
#       Successfully uninstalled platformdirs-2.5.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.1.2
#     Uninstalling pytest-7.1.2:
#       Successfully uninstalled pytest-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# statsmodels 0.13.5 requires packaging>=21.3, but you have packaging 21.0 which is incompatible.
# pytoolconfig 1.2.5 requires packaging>=22.0, but you have packaging 21.0 which is incompatible.
# jupyterlab-server 2.19.0 requires packaging>=21.3, but you have packaging 21.0 which is incompatible.
# Successfully installed cfgv-3.3.1 dash-iconify-0.1.2 dash-mantine-components-0.10.2 dash-tools-1.11.1 distlib-0.3.7 docopt-0.6.2 filelock-3.12.2 gunicorn-21.2.0 identify-2.5.26 nodeenv-1.8.0 packaging-21.0 pipreqs-0.4.11 platformdirs-3.10.0 pre-commit-2.16.0 pytest-6.2.5 termcolor-1.1.0 virtualenv-20.24.2 visdcc-0.0.50 yarg-0.1.9 yolk3k-0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
#This data contains Regional Under five mortality  projection up to 2025 with out separating neonatal and Infant
data=pd.read_csv('Regionaltrend.csv')

# %%
data.head()
# Out:
#    S/N  Year    Afar  Amhara  Benishangul Gumuz    Oromiya  Tigray  Somali  \
# 0    1  2016  84.745   50.15              72.81  55.028463   39.69  68.438
# 1    2  2017  77.180   45.83              66.56  50.280000   36.27  62.640
# 2    3  2018  73.400   43.59              63.30  47.820000   34.50  59.580
# 3    4  2019  70.000   41.54              60.33  45.570000   32.87  56.780
# 4    5  2020  66.820   39.68              57.63  43.530000   31.41  54.240
#
#    Southern Nations   Gambela  Harari  Dire Dawa  Addis Ababa
# 0              43.85   57.423  67.768    46.0337       30.368
# 1              40.04   52.470  61.930    41.9300       27.730
# 2              38.08   49.900  58.900    39.8800       26.370
# 3              36.29   47.560  56.120    38.0000       25.140
# 4              34.66   45.430  53.620    36.3000       24.010

# %%
df1.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
#Test For Regional Under Five mortality trend

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import socket
import dash_bootstrap_components as dbc
#host=socket.gethostname()
#port=50007

app = Dash(__name__)

#server=app.server
app.layout = html.Div([
    
    html.H4('Regional Under Five Mortality Trend'),
    html.P("Select Region:"),
    dcc.Dropdown(
        id="time-series-x-ticker",
        options=["Oromiya", "Amhara","Tigray","Somali","Southern Nations ","Afar","Gambela","Benishangul Gumuz","Harari","Dire Dawa","Addis Ababa"],
        value="Oromiya",
        clearable=False,
        
    ),
    dcc.Graph(id="time-series-x-time-series-chart"),
   
])


@app.callback(
    Output("time-series-x-time-series-chart", "figure"), 
    Input("time-series-x-ticker", "value"))
def display_time_series(ticker):
    df1 =pd.read_csv('Regionaltrend.csv') # replace with your own data source
    fig = px.line(df1, x='Year', y=ticker)
    return fig


if __name__ == "__main__":
    app.run_server(port = 9068, debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:9068/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import os
from os import kill
from os import getpid
from signal import SIGKILL

# %%
pid = os.getpid()

# %%
kill(pid, SIGKILL)
